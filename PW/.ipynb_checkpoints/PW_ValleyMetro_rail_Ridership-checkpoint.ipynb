# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from config import am_key

# %%
rail_stops = pd.read_csv(r'../CSVs/rail_stops_zipcodes.csv')

    
rail_stops
# Out:
#     Unnamed: 0           X          Y  StationId  \
# 0            0 -112.100759  33.567397          1
# 1            1 -111.830646  33.415107         35
# 2            2 -112.099629  33.552071          2
# 3            3 -112.099701  33.537384          3
# 4            4 -111.987983  33.448170         21
# ..         ...         ...        ...        ...
# 83          83 -112.075240  33.447774         16
# 84          84 -111.822144  33.415064         36
# 85          85 -111.974741  33.446930         22
# 86          86 -111.802802  33.415236         37
# 87          87 -111.790306  33.415317         38
#
#                       StationName Jurisdiction StationStatus     POINT_X  \
# 0     19th Avenue / Dunlap Avenue      Phoenix  In Operation -112.099389
# 1     Center Street / Main Street         Mesa  In Operation -111.830660
# 2   19th Avenue / Northern Avenue      Phoenix  In Operation -112.099360
# 3   19th Avenue / Glendale Avenue      Phoenix  In Operation -112.099329
# 4        44th Street / Washington      Phoenix  In Operation -111.987983
# ..                            ...          ...           ...         ...
# 83         Jefferson / 1st Avenue      Phoenix  In Operation -112.075202
# 84       Mesa Drive / Main Street         Mesa  In Operation -111.822191
# 85       50th St / Washington St       Phoenix  In Operation -111.974741
# 86           Main St / Stapley Dr         Mesa  In Operation -111.804935
# 87           Main St / Gilbert Rd         Mesa  In Operation -111.789026
#
#       POINT_Y  NextRide                      Address  Zipcode  \
# 0   33.567090     18608            1935 W Dunlap Ave    85021
# 1   33.415098     18602          26 East Main Street    85201
# 2   33.553190     18607              7832 N 19th Ave    85021
# 3   33.538643     18606              6813 N 19th Ave    85015
# 4   33.448170     10018  4203 East Washington Street    85034
# ..        ...       ...                          ...      ...
# 83  33.447774     10013          70 South 1st Avenue    85003
# 84  33.415078     18603         424 East Main Street    85203
# 85  33.446930     18716  4835 East Washingtpm Street    85034
# 86  33.415238     18717        1310 East Main Street    85203
# 87  33.415376     18718        1864 East Main Street    85203
#
#                city        street_address
# 0           Phoenix     1923 W DUNLAP AVE
# 1             Globe          20 E MAIN ST
# 2           Phoenix       7835 N 19TH AVE
# 3   Paradise Valley       6808 N 19TH AVE
# 4           Phoenix  4300 E WASHINGTON ST
# ..              ...                   ...
# 83          Phoenix     1 W WASHINGTON ST
# 84             Mesa         420 E MAIN ST
# 85          Phoenix  5001 E WASHINGTON ST
# 86             Mesa        1306 E MAIN ST
# 87             Mesa        1907 E MAIN ST
#
# [88 rows x 14 columns]

# %%
rail_stops = rail_stops.loc[rail_stops["StationStatus"] == 'In Operation']

# %%
rail_stops

# %%
url = 'https://geoservices.tamu.edu/Services/ReverseGeocoding/WebService/v04_01/Rest/\''
    
query_url = f"{url}appKey={am_key}&version='4.10'&q={stops}"


address = []
city = []
zipcode = []

stops = rail_stops['x','y']
