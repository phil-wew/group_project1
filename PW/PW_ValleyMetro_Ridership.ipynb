# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from config import am_key

# %%
rail_stops = pd.read_csv(r'../CSVs/Valley_Metro_Light_Rail_Stations_View.csv')

    
rail_stops
del rail_stops['TVM'] 
del rail_stops['Image']     
del rail_stops['Image2']  
del rail_stops['BikeRacks'] 
del rail_stops['WaterFountain'] 
del rail_stops['Restroom'] 
del rail_stops['InfoDisplay'] 
del rail_stops['Em_Call']
del rail_stops['Bench'] 
del rail_stops['TrashCan']

# %%
rail_stops = rail_stops.loc[rail_stops["StationStatus"] == 'In Operation']

# %%
rail_stops
# Out:
#              X          Y  OBJECTID  StationId                    StationName  \
# 0  -112.100759  33.567397         1          1    19th Avenue / Dunlap Avenue
# 1  -111.830646  33.415107         2         35    Center Street / Main Street
# 2  -112.099629  33.552071         3          2  19th Avenue / Northern Avenue
# 3  -112.099701  33.537384         4          3  19th Avenue / Glendale Avenue
# 4  -111.987983  33.448170         5         21       44th Street / Washington
# ..         ...        ...       ...        ...                            ...
# 83 -112.075240  33.447774        87         16         Jefferson / 1st Avenue
# 84 -111.822144  33.415064        88         36       Mesa Drive / Main Street
# 85 -111.974741  33.446930        89         22       50th St / Washington St
# 86 -111.802802  33.415236        90         37           Main St / Stapley Dr
# 87 -111.790306  33.415317        91         38           Main St / Gilbert Rd
#
#    Jurisdiction StationStatus     POINT_X    POINT_Y  NextRide  \
# 0       Phoenix  In Operation -112.099389  33.567090     18608
# 1          Mesa  In Operation -111.830660  33.415098     18602
# 2       Phoenix  In Operation -112.099360  33.553190     18607
# 3       Phoenix  In Operation -112.099329  33.538643     18606
# 4       Phoenix  In Operation -111.987983  33.448170     10018
# ..          ...           ...         ...        ...       ...
# 83      Phoenix  In Operation -112.075202  33.447774     10013
# 84         Mesa  In Operation -111.822191  33.415078     18603
# 85      Phoenix  In Operation -111.974741  33.446930     18716
# 86         Mesa  In Operation -111.804935  33.415238     18717
# 87         Mesa  In Operation -111.789026  33.415376     18718
#
#                         Address
# 0             1935 W Dunlap Ave
# 1           26 East Main Street
# 2               7832 N 19th Ave
# 3               6813 N 19th Ave
# 4   4203 East Washington Street
# ..                          ...
# 83          70 South 1st Avenue
# 84         424 East Main Street
# 85  4835 East Washingtpm Street
# 86        1310 East Main Street
# 87        1864 East Main Street
#
# [88 rows x 11 columns]

# %%
url = 'https://geoservices.tamu.edu/Services/ReverseGeocoding/WebService/v04_01/Rest/?'
version = 4.1
query_url = f"{url}apiKey={am_key}&version=4.10&format=json&state=az&notStore=false"


zipcode = []


for index,row in rail_stops.iterrows():
    query_api = query_url+'&lat='+str(row['Y'])+'&lon='+str(row['X'])
    response = requests.get(query_api).json()
    zipcode.append(response['StreetAddresses'][0]['Zip'])
    city.append(response['StreetAddresses'][0]['City'])
    address.append(response['StreetAddresses'][0]['StreetAddress'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e7a025712c35> in <module>
#      11     response = requests.get(query_api).json()
#      12     zipcode.append(response['StreetAddresses'][0]['Zip'])
# ---> 13     city.append(response['StreetAddresses'][0]['City'])
#      14     address.append(response['StreetAddresses'][0]['StreetAddress'])
#
# NameError: name 'city' is not defined

# %%
rail_stops['Zipcode'] = zipcode
rail_stops

# %%
del rail_stops['OBJECTID']

# %%
bus_stops = pd.read_csv(r'../CSVs/Valley_Metro_Bus_Stops_View_UPDATED.csv')
 
filter_bus = bus_stops.loc[(bus_stops['Juris'] == 'Mesa') | (bus_stops['Juris'] == 'Phoenix') | (bus_stops['Juris'] == 'Tempe'), :]

# %%
filter_bus
# Out:
#                X          Y  OBJECTID   StopID  NextRide  \
# 1402 -111.823076  33.414719       1.0   5182.0   16020.0
# 1403 -111.822766  33.415684       2.0   2982.0   16001.0
# 1404 -111.822935  33.425734       3.0   4681.0   16016.0
# 1405 -111.823048  33.422048       4.0   4682.0   16017.0
# 1406 -111.823069  33.416883       5.0   4679.0   16019.0
# ...          ...        ...       ...      ...       ...
# 7620 -111.936082  33.425628    7732.0  30369.0       NaN
# 7621 -111.936284  33.425629    7733.0  30369.0       NaN
# 7622 -111.936458  33.425619    7734.0  30369.0       NaN
# 7623 -111.930397  33.458342    7746.0  30430.0   18787.0
# 7624 -111.900373  33.422489    7751.0      NaN   18781.0
#
#                                      Location  Juris  Shelter  Bench  \
# 1402                        MESA DR & MAIN ST   Mesa      1.0    1.0
# 1403                        MESA DR & MAIN ST   Mesa      1.0    4.0
# 1404                         MESA DR & 6TH ST   Mesa      1.0    1.0
# 1405                  MESA DR & UNIVERSITY DR   Mesa      1.0    1.0
# 1406                         MESA DR & 1ST ST   Mesa      0.0    1.0
# ...                                       ...    ...      ...    ...
# 7620              Tempe Transportation Center  Tempe      1.0    1.0
# 7621              Tempe Transportation Center  Tempe      1.0    1.0
# 7622              Tempe Transportation Center  Tempe      1.0    1.0
# 7623  E. Continental Dr. & N. McAllister Ave.  Tempe      0.0    0.0
# 7624         S. Smith St. & E. University Dr.  Tempe      0.0    0.0
#
#       TrashCan  ... Info_Display           Type_   DateUpdated Sidewalk  \
# 1402       0.0  ...           No        Standard  1.541150e+12      NaN
# 1403       1.0  ...          Yes            LINK  1.541150e+12      Yes
# 1404       1.0  ...           No        Standard  1.541150e+12      Yes
# 1405       1.0  ...           No        Standard  1.541150e+12      Yes
# 1406       1.0  ...           No        Standard  1.541150e+12      Yes
# ...        ...  ...          ...             ...           ...      ...
# 7620       1.0  ...          Yes  Transit Center  1.552260e+12      Yes
# 7621       1.0  ...          Yes  Transit Center  1.552260e+12      Yes
# 7622       1.0  ...          Yes  Transit Center  1.552260e+12      Yes
# 7623       0.0  ...           No        Standard  1.561330e+12      Yes
# 7624       0.0  ...           No        Standard  1.561330e+12      Yes
#
#                                                   Photo  ATIS_ID   Direction  \
# 1402  https://farm9.staticflickr.com/8719/1692170720...   5196.0  Southbound
# 1403  https://farm1.staticflickr.com/757/21334866928...   2996.0  Northbound
# 1404  https://farm8.staticflickr.com/7288/1632759920...   4695.0  Southbound
# 1405  https://farm9.staticflickr.com/8622/1630995151...   4696.0  Southbound
# 1406  https://farm8.staticflickr.com/7292/1587753502...   4693.0  Southbound
# ...                                                 ...      ...         ...
# 7620                                                NaN      NaN       Other
# 7621                                                NaN      NaN       Other
# 7622                                                NaN      NaN       Other
# 7623                                                NaN  13012.0   Eastbound
# 7624                                                NaN      NaN  Northbound
#
#             Long        Lat       Routes
# 1402 -111.823076  33.414719          120
# 1403 -111.822766  33.415684          120
# 1404 -111.822935  33.425734          120
# 1405 -111.823048  33.422048          120
# 1406 -111.823069  33.416883          120
# ...          ...        ...          ...
# 7620 -111.936082  33.425628       VENU B
# 7621 -111.936284  33.425629         FSHB
# 7622 -111.936458  33.425619          DAR
# 7623 -111.930397  33.458342  68CM | EART
# 7624 -111.900373  33.422489           62
#
# [5535 rows x 28 columns]

# %%
filter_bus.to_csv(r'../CSVs/filter_bus.csv')

# %%
first_bus = filter_bus.iloc[0:1500]

# %%
first_bus
# Out:
#                X          Y  OBJECTID  StopID  NextRide  \
# 1402 -111.823076  33.414719       1.0  5182.0   16020.0
# 1403 -111.822766  33.415684       2.0  2982.0   16001.0
# 1404 -111.822935  33.425734       3.0  4681.0   16016.0
# 1405 -111.823048  33.422048       4.0  4682.0   16017.0
# 1406 -111.823069  33.416883       5.0  4679.0   16019.0
# ...          ...        ...       ...     ...       ...
# 3055 -112.104016  33.473137    4263.0  7869.0   11406.0
# 3056 -112.104636  33.473279    4264.0  7870.0   11405.0
# 3057 -112.169068  33.458837    4265.0  7871.0   10453.0
# 3058 -112.169034  33.463966    4266.0  7872.0   13447.0
# 3059 -112.169261  33.465408    4267.0  7873.0   13528.0
#
#                      Location    Juris  Shelter  Bench  TrashCan  ...  \
# 1402        MESA DR & MAIN ST     Mesa      1.0    1.0       0.0  ...
# 1403        MESA DR & MAIN ST     Mesa      1.0    4.0       1.0  ...
# 1404         MESA DR & 6TH ST     Mesa      1.0    1.0       1.0  ...
# 1405  MESA DR & UNIVERSITY DR     Mesa      1.0    1.0       1.0  ...
# 1406         MESA DR & 1ST ST     Mesa      0.0    1.0       1.0  ...
# ...                       ...      ...      ...    ...       ...  ...
# 3055  ENCANTO BLVD & 21ST AVE  Phoenix      NaN    NaN       NaN  ...
# 3056  ENCANTO BLVD & 21ST AVE  Phoenix      NaN    NaN       NaN  ...
# 3057  51ST AVE & ROOSEVELT ST  Phoenix      NaN    NaN       NaN  ...
# 3058      51ST AVE & I-10 FWY  Phoenix      NaN    NaN       NaN  ...
# 3059   51ST AVE & MCDOWELL RD  Phoenix      NaN    NaN       NaN  ...
#
#      Info_Display     Type_   DateUpdated Sidewalk  \
# 1402           No  Standard  1.541150e+12      NaN
# 1403          Yes      LINK  1.541150e+12      Yes
# 1404           No  Standard  1.541150e+12      Yes
# 1405           No  Standard  1.541150e+12      Yes
# 1406           No  Standard  1.541150e+12      Yes
# ...           ...       ...           ...      ...
# 3055          NaN       NaN  1.541150e+12      NaN
# 3056          NaN       NaN  1.541150e+12      NaN
# 3057          NaN       NaN  1.541150e+12      NaN
# 3058          NaN       NaN  1.541150e+12      NaN
# 3059          NaN       NaN  1.541150e+12      NaN
#
#                                                   Photo ATIS_ID   Direction  \
# 1402  https://farm9.staticflickr.com/8719/1692170720...  5196.0  Southbound
# 1403  https://farm1.staticflickr.com/757/21334866928...  2996.0  Northbound
# 1404  https://farm8.staticflickr.com/7288/1632759920...  4695.0  Southbound
# 1405  https://farm9.staticflickr.com/8622/1630995151...  4696.0  Southbound
# 1406  https://farm8.staticflickr.com/7292/1587753502...  4693.0  Southbound
# ...                                                 ...     ...         ...
# 3055                                                NaN     NaN         NaN
# 3056                                                NaN     NaN         NaN
# 3057                                                NaN     NaN         NaN
# 3058                                                NaN     NaN         NaN
# 3059                                                NaN     NaN         NaN
#
#             Long        Lat Routes
# 1402 -111.823076  33.414719    120
# 1403 -111.822766  33.415684    120
# 1404 -111.822935  33.425734    120
# 1405 -111.823048  33.422048    120
# 1406 -111.823069  33.416883    120
# ...          ...        ...    ...
# 3055 -112.104016  33.473137    GAL
# 3056 -112.104636  33.473279    GAL
# 3057 -112.169068  33.458837     51
# 3058 -112.169034  33.463966     51
# 3059 -112.169261  33.465408     51
#
# [1500 rows x 28 columns]
