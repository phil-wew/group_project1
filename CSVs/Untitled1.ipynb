# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# %%
new_csv = "../CSVs/filter_bus_1000.csv"
new_stops_df = pd.read_csv(new_csv,encoding="utf-8")

new_stops_df.head()
# Out:
#    NoName           X          Y  StopID  NextRide                 Location  \
# 0     0.0 -111.823076  33.414719  5182.0   16020.0        MESA DR & MAIN ST
# 1     1.0 -111.822766  33.415684  2982.0   16001.0        MESA DR & MAIN ST
# 2     2.0 -111.822934  33.425734  4681.0   16016.0         MESA DR & 6TH ST
# 3     3.0 -111.823048  33.422048  4682.0   16017.0  MESA DR & UNIVERSITY DR
# 4     4.0 -111.823069  33.416883  4679.0   16019.0         MESA DR & 1ST ST
#
#   Juris WaterFountain  ADA     Type_  ...  TransactionId  \
# 0  Mesa            No   No  Standard  ...            NaN
# 1  Mesa            No   No      LINK  ...            NaN
# 2  Mesa            No  Yes  Standard  ...            NaN
# 3  Mesa            No  Yes  Standard  ...            NaN
# 4  Mesa            No  Yes  Standard  ...            NaN
#
#                  Source  ErrorMessage  Version ComputedAPN  \
# 0  AggieReverseGeocoder           NaN     4.01    13865023
# ...
