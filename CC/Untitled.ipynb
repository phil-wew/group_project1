# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

#from config import t_key

# %%
new_csv = "../CC/Jan2020VMBusStops-Copy2.csv"
#col_list = ['SERVICE', 'Avg Full Fare', 'Avg Exp Fare', 'Avg Reduced Fare', 'Avg Full Fare Pass', 'Avg Reduced Pass', 'Avg Monthly Pass', 'Avg Free', 'Avg Bikes', 'Avg W/C', 'Avg Daily']
#new_stops_df = pd.read_csv(new_csv,"utf-8", engine='python', usecols=col_list)
new_stops_df = pd.read_csv(new_csv,"utf-8", engine='python', delimiter = ",")

new_stops_df.head()
# Out:
#   SERVICE              ROUTE CITY  Avg Full Fare  Avg Exp Fare  \
# 0      WK  Valley Metro Rail  Mes            161             0
# 1      WK  Valley Metro Rail  Phx            741             0
# 2      WK  Valley Metro Rail  Tem            332             0
# 3      SA  Valley Metro Rail  Mes            122             0
# 4      SA  Valley Metro Rail  Phx            527             0
#
#    Avg Reduced Fare Avg Full Fare Pass Avg Reduced Pass Avg Monthly Pass  \
# 0               218              2,802            3,496              467
# 1               601              9,943           11,726            2,690
# 2               276              2,716            3,354            1,732
# 3               165              2,117            2,642              353
# 4               427              7,065            8,331            1,911
#
#   Avg Free  Avg Bikes  Avg W/C  Avg Daily Boardings  Total Boardings   \
# 0      836          0        0                7,980           175,538
# ...

# %%
new_stops_df.dtypes
# Out:
# SERVICE,ROUTE,CITY,Avg Full Fare,Avg Exp Fare,Avg Reduced Fare,Avg Full Fare Pass,Avg Reduced Pass,Avg Monthly Pass,Avg Free,Avg Bikes,Avg W/C, Avg Daily Boardings, Total Boardings ,Daily Revenue Miles,Total Rev. Miles,Boardings Per Rev Mile,1/19 - Avg Daily,% Difference    object
# dtype: object
